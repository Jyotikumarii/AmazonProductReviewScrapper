# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://www.mouthshut.com/televisions/LG-42LF5530-106-cm-42-LED-TV-Full-HD-reviews-925790811'

# %%
page_details=requests.get(url)
soup=bs(page_details.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head id="ctl00_ctl00_Head1">
#   <meta content="P6Kqf7KhXgEvVAg-ZcEtxTLDJ-aXEVi7NsRPIDpgE2Q" name="google-site-verification"/>
#   <title>
#    LG 42LF5530 106 CM (42) LED TV (FULL HD) - Reviews | Price | Specifications | Compare
#   </title>
#   <style>
#    .surveylayer {
#             position: fixed;
#             z-index: 1111;
#             background: #fff;
#             left: 34%;
#             top: -581px;
#             border-radius: 5px;
#         }
#
#             .surveylayer section {
#                 margin: 0;
#                 padding: 1px;
#             }
#
#         .surveylayerclose {
#             position: absolute;
#             top: 11px;
#             right: 11px;
#             font-weight: 900 !important;
#             /* background-color: #6f9d20; */
#             padding: 10px;
# ...

# %%
results = soup.find('a', id='rptreviews_ctl00_lnkTitle')
print(results)
# Out:
# None
